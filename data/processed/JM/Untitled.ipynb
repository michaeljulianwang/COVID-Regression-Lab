# %%
import pandas as pd

# %%
df = pd.read_csv('2020_Mobility_Report_FW.csv')

# %%
dfpivot = df.pivot(index='Date',columns='State_code',values='RR_change')

# %%
dfpivot
# Out:
# State_code  AK  AL  AR  AZ  CA  CO  CT  DC  DE  FL  ...  SD  TN  TX  UT  VA  \
# Date                                                ...
# 3/15/2020    5  -7  -5  -2 -16 -14 -13 -35  -7  -9  ...  -8  -8  -9  -6 -14
# 3/16/2020    1  -2  -6   0 -12  -7  -7 -31   0  -6  ...  -7  -4  -4  -7  -7
# 3/17/2020  -14 -11 -10  -9 -23 -24 -27 -40 -17 -11  ...  -8 -10 -12 -18 -13
# 3/18/2020  -19 -13 -12 -23 -29 -26 -27 -45 -23 -19  ... -14 -15 -16 -26 -21
# 3/19/2020  -26 -20 -18 -22 -32 -46 -33 -46 -26 -23  ... -29 -17 -22 -30 -23
# ...         ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..
# 6/5/2020     3 -10  -4 -21 -36 -19 -20 -56 -16 -23  ...   0  -8 -14 -13 -22
# 6/6/2020     2 -11  -9 -23 -37 -26 -17 -53 -12 -28  ... -10  -8 -18 -22 -23
# 6/7/2020    15 -15  -4 -19 -35 -14 -13 -51  -9 -27  ...   9  -5 -15 -14 -19
# 6/8/2020     3 -10 -10 -14 -32 -13 -10 -51  -6 -22  ...   6  -4 -13  -9 -16
# 6/9/2020     7  -8   0 -15 -32 -15 -11 -51  -4 -20  ...   1  -3 -12  -7 -15
#
# ...

# %%
dfpivot.to_csv('mobility_unstacked.csv')
